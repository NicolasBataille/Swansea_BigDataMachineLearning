# %% [markdown]
# ### Nicolas Bataille
# 07/11/2021\
# Student number : 2131029

# %%
# Import packages
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
# Out:
# 2021-11-08 14:30:52.160600: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-11-08 14:30:52.160638: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ### Task 4.1

# %%
wineData = np.load('Datas/wineData.npy')
wineLabels = np.load('Datas/wineLabels.npy')

wineDataTrain, wineDataTest, wineLabelsTrain, wineLabelsTest = train_test_split(wineData, wineLabels, test_size=0.2)

# %%
plt.figure()
plt.scatter(wineDataTrain[:,0], 
            wineDataTrain[:,1],
            c = wineLabelsTrain)
plt.title('Original training Data')
plt.xlabel('Feature Dimension 0')
plt.ylabel('Feature Dimension 1')
plt.show()

# %% [markdown]
# #### Data Standardisation

# %%
standardScaler = StandardScaler()

standardScaler.fit(wineDataTrain)

wineDataTrain = standardScaler.transform(wineDataTrain)
wineDataTest = standardScaler.transform(wineDataTest)

# %% [markdown]
# #### Creating and training a multiclass SVM

# %%
SVM = SVC()
SVM.fit(wineDataTrain, wineLabelsTrain)
# Out:
# SVC()

# %% [markdown]
# #### Predicting labels on the testing set

# %%
wineDataTestPrediction = SVM.predict(wineDataTest)

winePredictionAccuracy = SVM.score(wineDataTest, wineLabelsTest)
print(f'The model accuracy on the testing data is {winePredictionAccuracy*100:0.2f}%')
# Out:
# The model accuracy on the testing data is 100.00%

# %%
plt.figure(figsize=[10,5])

plt.subplot(121)
plt.scatter(wineDataTest[:,0],
            wineDataTest[:,1],
            c = wineLabelsTest)
plt.title('Ground Truth')
plt.xlabel('Feature Dimension 0')
plt.ylabel('Feature Dimension 1')

plt.subplot(122)
plt.scatter(wineDataTest[:,0],
            wineDataTest[:,1],
            c = wineDataTestPrediction)
plt.title('Predicted Labels')
plt.xlabel('Feature Dimension 0')
plt.ylabel('Feature Dimension 1')

plt.show()

# %% [markdown]
# ### Task 4.2

# %% [markdown]
# ### Creating a Tensorflow Fully Connected Neural Network with a Sequential Model

# %%
outputSize = len(np.unique(wineLabelsTrain))

# note: Dense layers are fully connected layers
model = tf.keras.Sequential(layers=[
    tf.keras.layers.Dense(4, activation = tf.nn.relu),
    tf.keras.layers.Dense(10, activation = tf.nn.relu),
    tf.keras.layers.Dense(outputSize, activation = tf.nn.softmax)
])

model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
              metrics=tf.keras.metrics.SparseCategoricalAccuracy())
# Out:
# 2021-11-08 14:30:55.010008: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-11-08 14:30:55.010036: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-08 14:30:55.010057: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Batum-Laptop): /proc/driver/nvidia/version does not exist
# 2021-11-08 14:30:55.010295: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Training the model on the data

# %%
history = model.fit(wineDataTrain, 
            wineLabelsTrain, 
            epochs = 100,
            validation_split = 0.2,
            verbose = 1)
# Out:
# 2021-11-08 14:30:55.435466: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 4/4 [==============================] - 0s 46ms/step - loss: 1.4288 - sparse_categorical_accuracy: 0.2920 - val_loss: 1.5442 - val_sparse_categorical_accuracy: 0.2414
# Epoch 2/100
# 4/4 [==============================] - 0s 10ms/step - loss: 1.
- sparse_categorical_accuracy: 0.6549 - val_loss: 0.6910 - val_sparse_categorical_accuracy: 0.7586
# Epoch 55/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7401 - sparse_categorical_accuracy: 0.6549 - val_loss: 0.6839 - val_sparse_categorical_accuracy: 0.7586
# Epoch 56/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7342 - sparse_categorical_accuracy: 0.6549 - val_loss: 0.6771 - val_sparse_categorical_accuracy: 0.7586
# Epoch 57/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7286 - sparse_categorical_accuracy: 0.6549 - val_loss: 0.6705 - val_sparse_categorical_accuracy: 0.7586
# Epoch 58/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7231 - sparse_categorical_accuracy: 0.6549 - val_loss: 0.6640 - val_sparse_categorical_accuracy: 0.7586
# Epoch 59/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7177 - sparse_categorical_accuracy: 0.6549 - val_loss: 0.6575 - val_sparse_categorical_accuracy: 0.7586
# Epoch 60/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7125 - sparse_categorical_accuracy: 0.6549 - val_loss: 0.6514 - val_sparse_categorical_accuracy: 0.7586
# Epoch 61/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7075 - sparse_categorical_accuracy: 0.6549 - val_loss: 0.6448 - val_sparse_categorical_accuracy: 0.7586
# Epoch 62/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7020 - sparse_categorical_accuracy: 0.6549 - val_loss: 0.6388 - val_sparse_categorical_accuracy: 0.7586
# Epoch 63/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6966 - sparse_categorical_accuracy: 0.6637 - val_loss: 0.6328 - val_sparse_categorical_accuracy: 0.7586
# Epoch 64/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6914 - sparse_categorical_accuracy: 0.6726 - val_loss: 0.6269 - val_sparse_categorical_accuracy: 0.7586
# Epoch 65/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6862 - sparse_categorical_accuracy: 0.6726 - val_loss: 0.6209 - val_sparse_categorical_accuracy: 0.7586
# Epoch 66/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6809 - sparse_categorical_accuracy: 0.6726 - val_loss: 0.6151 - val_sparse_categorical_accuracy: 0.7586
# Epoch 67/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6760 - sparse_categorical_accuracy: 0.6726 - val_loss: 0.6095 - val_sparse_categorical_accuracy: 0.7586
# Epoch 68/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6709 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.6037 - val_sparse_categorical_accuracy: 0.7586
# Epoch 69/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6659 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5980 - val_sparse_categorical_accuracy: 0.7586
# Epoch 70/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6611 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5923 - val_sparse_categorical_accuracy: 0.7586
# Epoch 71/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6561 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5867 - val_sparse_categorical_accuracy: 0.7586
# Epoch 72/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6513 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5811 - val_sparse_categorical_accuracy: 0.7586
# Epoch 73/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6467 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5755 - val_sparse_categorical_accuracy: 0.7586
# Epoch 74/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6419 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5701 - val_sparse_categorical_accuracy: 0.7586
# Epoch 75/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6373 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5650 - val_sparse_categorical_accuracy: 0.7586
# Epoch 76/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6327 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5600 - val_sparse_categorical_accuracy: 0.7586
# Epoch 77/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6283 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5551 - val_sparse_categorical_accuracy: 0.7586
# Epoch 78/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6238 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5501 - val_sparse_categorical_accuracy: 0.7586
# Epoch 79/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6196 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5450 - val_sparse_categorical_accuracy: 0.7586
# Epoch 80/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6154 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5404 - val_sparse_categorical_accuracy: 0.7586
# Epoch 81/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6112 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5355 - val_sparse_categorical_accuracy: 0.7586
# Epoch 82/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6068 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5303 - val_sparse_categorical_accuracy: 0.7586
# Epoch 83/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6024 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5253 - val_sparse_categorical_accuracy: 0.7586
# Epoch 84/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5982 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5202 - val_sparse_categorical_accuracy: 0.7586
# Epoch 85/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5938 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5153 - val_sparse_categorical_accuracy: 0.7586
# Epoch 86/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5898 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5108 - val_sparse_categorical_accuracy: 0.7586
# Epoch 87/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5853 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5060 - val_sparse_categorical_accuracy: 0.7586
# Epoch 88/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5810 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.5011 - val_sparse_categorical_accuracy: 0.7586
# Epoch 89/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5766 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.4963 - val_sparse_categorical_accuracy: 0.7586
# Epoch 90/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5722 - sparse_categorical_accuracy: 0.6903 - val_loss: 0.4917 - val_sparse_categorical_accuracy: 0.7586
# Epoch 91/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5680 - sparse_categorical_accuracy: 0.6903 - val_loss: 0.4874 - val_sparse_categorical_accuracy: 0.7586
# Epoch 92/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5636 - sparse_categorical_accuracy: 0.6903 - val_loss: 0.4831 - val_sparse_categorical_accuracy: 0.7586
# Epoch 93/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5591 - sparse_categorical_accuracy: 0.6903 - val_loss: 0.4790 - val_sparse_categorical_accuracy: 0.7586
# Epoch 94/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5549 - sparse_categorical_accuracy: 0.6903 - val_loss: 0.4747 - val_sparse_categorical_accuracy: 0.7586
# Epoch 95/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5506 - sparse_categorical_accuracy: 0.6903 - val_loss: 0.4702 - val_sparse_categorical_accuracy: 0.7586
# Epoch 96/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5463 - sparse_categorical_accuracy: 0.6903 - val_loss: 0.4661 - val_sparse_categorical_accuracy: 0.7586
# Epoch 97/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5419 - sparse_categorical_accuracy: 0.6903 - val_loss: 0.4619 - val_sparse_categorical_accuracy: 0.7586
# Epoch 98/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5378 - sparse_categorical_accuracy: 0.6903 - val_loss: 0.4577 - val_sparse_categorical_accuracy: 0.7586
# Epoch 99/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5334 - sparse_categorical_accuracy: 0.6903 - val_loss: 0.4536 - val_sparse_categorical_accuracy: 0.7586
# Epoch 100/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5293 - sparse_categorical_accuracy: 0.6991 - val_loss: 0.4495 - val_sparse_categorical_accuracy: 0.7586

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 4)                 56
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                50
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 139
# Trainable params: 139
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Get the predicted labels on the Testing dataset
SVMPredict = model.predict(wineDataTest)
# Get the loss and accuracy of the model on the Testing dataset
results = model.evaluate(wineDataTest, wineLabelsTest)
print(f'The accuracy is {results[1]*100:0.2f}%')
# Out:
# (36, 3)
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5305 - sparse_categorical_accuracy: 0.6944
# The accuracy is 69.44%

# %%
plt.figure(figsize=[10,5])

plt.subplot(121)
plt.scatter(wineDataTest[:,0],
            wineDataTest[:,1],
            c = wineLabelsTest)
plt.title('Ground Truth')
plt.xlabel('Feature Dimension 0')
plt.ylabel('Feature Dimension 1')

plt.subplot(122)
plt.scatter(wineDataTest[:,0],
            wineDataTest[:,1],
            c = np.argmax(SVMPredict),
            axis = 1)
plt.title('Predicted Labels')
plt.xlabel('Feature Dimension 0')
plt.ylabel('Feature Dimension 1')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4349             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4350                 colors = mcolors.to_rgba_array(c)
#    4351             except (TypeError, ValueError) as err:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     370
# --> 371     if len(c) == 0:
#     372         return np.zeros((0, 4), float)
#
# TypeError: len() of unsized object
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2994/3468419433.py in <module>
#      10
#      11 plt.subplot(122)
# ---> 12 plt.scatter(wineDataTest[:,0],
#      13             wineDataTest[:,1],
#      14             c = np.argmax(SVMPredict),
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3066         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    3067         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 3068     __ret = gca().scatter(
#    3069         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3070         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4514             orig_edgecolor = kwargs.get('edgecolor', None)
#    4515         c, colors, edgecolors = \
# -> 4516             self._parse_scatter_color_args(
#    4517                 c, edgecolors, kwargs, x.size,
#    4518                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4354                 else:
#    4355                     if not valid_shape:
# -> 4356                         raise invalid_shape_exception(c.size, xsize) from err
#    4357                     # Both the mapping *and* the RGBA conversion failed: pretty
#    4358                     # severe failure => one may appreciate a verbose feedback.
#
# ValueError: 'c' argument has 1 elements, which is inconsistent with 'x' and 'y' with size 36.
