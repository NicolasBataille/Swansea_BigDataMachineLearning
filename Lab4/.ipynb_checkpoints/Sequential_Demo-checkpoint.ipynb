# %% [markdown]
# # Lab 4 - SVMs, NN, CNN
# # Tensorflow Neural Network example on Fisher Iris Dataset

# %%
import tensorflow as tf
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# 2021-11-07 22:44:47.028199: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-11-07 22:44:47.028226: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Load in the Iris data and divide it into training and testing sets

# %%
iris_data = np.load('Iris_data.npy')
iris_labels = np.load('Iris_labels.npy')

X_trn, X_tst, y_trn, y_tst = train_test_split(iris_data, iris_labels, test_size=0.2)

# %% [markdown]
# ##### Print out some stats about the data

# %%
print(f'Number of features: {X_trn.shape[1]}')
print(f'Number of training samples: {X_trn.shape[0]}')
print(f'Number of testing samples: {X_tst.shape[0]}')
print(f'Number of classes: {len(np.unique(y_trn))}')
print(f'Minimums of the features are: {X_trn.min(0)}')
print(f'Maximums of the features are: {X_trn.max(0)}')
# Out:
# Number of features: 4
# Number of training samples: 120
# Number of testing samples: 30
# Number of classes: 3
# Minimums of the features are: [4.3 2.  1.  0.1]
# Maximums of the features are: [7.9 4.4 6.7 2.5]

# %% [markdown]
# ##### Plot the first two feautre dimensions against eachother, colouring by class label

# %%
plt.figure()
plt.scatter(X_trn[:,0], X_trn[:,1], c=y_trn)
plt.xlabel('Feature Dimension 0')
plt.ylabel('Feature Dimension 1')
plt.title('Original Data')
# Out:
# Text(0.5, 1.0, 'Original Data')

# %% [markdown]
# ## Data Standardisation

# %% [markdown]
# #### The loaded data is not standardised, as can be seen by the range covered in each feature dimension.
# Often it can be useful to standardise our feature dimensions to give them a mean of zero and a scaled variance. Many algorithms, or components of an model, presume a zero-centred and scaled variance domain. applying this standardisation can often be critical to efficient learning.
#
# #### We can use StandardScaler from the sklearn package to standardise our data based on the observed training samples.
# First, we will create a `StandardScaler` object. We then `fit` it to our training data, and then `transform` both our training and testing data using this fit model.

# %%
## Normalise the data (helps with convergence)
normaliser = StandardScaler()
X_trn = normaliser.fit_transform(X_trn)
X_tst = normaliser.transform(X_tst)

# %%
print(f'Minimums of the features are: {X_trn.min(0)}')
print(f'Maximums of the features are: {X_trn.max(0)}')

plt.figure()
plt.scatter(X_trn[:,0], X_trn[:,1], c=y_trn)
plt.xlabel('Feature Dimension 0')
plt.ylabel('Feature Dimension 1')
plt.title('Standardised Data')
# Out:
# Minimums of the features are: [-1.85152052 -2.56740924 -1.59989514 -1.47868679]
# Maximums of the features are: [2.50974918 3.28238396 1.71223644 1.74022323]
# Text(0.5, 1.0, 'Standardised Data')

# %% [markdown]
# ## Building a Tensorflow Keras model

# %% [markdown]
# ##### Now we want to create a Fully-Connected Neural Network
# In this section we will create an instance of a `tensorflow.keras.Sequential` model. Sequential allows us to pass in a list of the layers we would like to apply, in the order we wish to apply them. This is an easy way to build very simple networks, where one layer is sequentially called on the outputs of the previous layer.
#
# Here we create an instance of the `Sequential` class, passing the constructor a list of the layers we wish to use. These layers are all implemented within `tensorflow.keras.layers`. For this example, we only use `Dense` layers, which is a fully connected layer. As we can see, each layer in the list is actually a constructor call, creating their own instance of a `Dense` object/layer in our model. This example creates a neural network with 2 hidden layers (with sizes 4 and 10 respectively), and an output layer of size `len(np.unique(y_trn))` (our number of classes in the dataset).
#
# In this example, the `Dense` layers takes as input to its constructor call: the number of units/neurons, and the activation function we wish to apply to the layer's output before it is fed to the next layer in the list.

# %%
model = tf.keras.Sequential(layers=[
    tf.keras.layers.Dense(4, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.relu),
    tf.keras.layers.Dense(len(np.unique(y_trn)), activation=tf.nn.softmax)])
# Out:
# 2021-11-07 22:44:49.316943: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-11-07 22:44:49.316973: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-07 22:44:49.316999: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Batum-Laptop): /proc/driver/nvidia/version does not exist
# 2021-11-07 22:44:49.317219: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### Now we need to compile our model, providing it with an optimiser, loss and metrics to train with
# We call the `compile()` method of our Sequential model object, passing in values for the arguments `optimizer`, `loss`, and `metrics`.
#
# * `optimizer` is an instance of a `tensorflow.keras.optimizers` class, and describes the optimization strategy used during the training of the model. In this example we use Stochastic Gradient Descent.
# * `loss` is an instance of a `tensorflow.keras.losses` class, and describes the loss to be used by the optimiser when training. In this example we use Sparse Categorical Cross-entropy, as our targets are class labels (i.e. not one-hot encoded)
# * `metric` is an instance of a `tensorflow.keras.metrics` class, and describes the accuracy metric we wish to calculate between our predictions and the ground truth. In this example we use Sparse Catergorical Accuracy as we want our accuracy to reflect the proportion of samples labelled correctly.

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
              metrics=tf.keras.metrics.SparseCategoricalAccuracy())

# %% [markdown]
# #### Now we can train out model, by calling the `fit()` function.
# We pass in our data (`X_trn`), target labels (`y_trn`), and a integer representing how many epochs we want to train our model to.
#
# We also pass a float value, `validation_split`, between 0.0 and 1.0 to further divide our training data into a training and validation set. The validation set is then used by the `fit()` method to evaluate how the model is progressing during training. This will help is see whether over- or under-fitting is occuring.
#
# We also set `verbose` to 1, so that we see the training progress printed to the console.
#
# The final thing we do is save the returned `tensorflow.keras.callbacks.History` object into the variable called history. This will let us view and plot the training curves later.

# %%
history = model.fit(X_trn, y_trn, epochs=100, validation_split=0.2, verbose=1)
# Out:
# 2021-11-07 22:44:49.543194: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 3/3 [==============================] - 1s 110ms/step - loss: 1.0961 - sparse_categorical_accuracy: 0.3333 - val_loss: 1.0547 - val_sparse_categorical_accuracy: 0.3750
# Epoch 2/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.0889 - sparse_categorical_accuracy: 0.3646 - val_loss: 1.0495 - val_sparse_categorical_accuracy: 0.3750
# Epoch 3/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0819 - sparse_categorical_accuracy: 0.3646 - val_loss: 1.0442 - val_sparse_categorical_accuracy: 0.3750
# Epoch 4/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0755 - sparse_categorical_accuracy: 0.3646 - val_loss: 1.0389 - val_sparse_categorical_accuracy: 0.3750
# Epoch 5/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0688 - sparse_categorical_accuracy: 0.3646 - val_loss: 1.0340 - val_sparse_categorical_accuracy: 0.3750
# Epoch 6/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0634 - sparse_categorical_accuracy: 0.3854 - val_loss: 1.0292 - val_sparse_categorical_accuracy: 0.3750
# Epoch 7/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0583 - sparse_categorical_accuracy: 0.4062 - val_loss: 1.0247 - val_sparse_categorical_accuracy: 0.3750
# Epoch 8/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0535 - sparse_categorical_accuracy: 0.4062 - val_loss: 1.0202 - val_sparse_categorical_accuracy: 0.3750
# Epoch 9/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0489 - sparse_categorical_accuracy: 0.4271 - val_loss: 1.0160 - val_sparse_categorical_accuracy: 0.3750
# Epoch 10/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0444 - sparse_categorical_accuracy: 0.4271 - val_loss: 1.0120 - val_sparse_categorical_accuracy: 0.3750
# Epoch 11/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0402 - sparse_categorical_accuracy: 0.4271 - val_loss: 1.0082 - val_sparse_categorical_accuracy: 0.3750
# Epoch 12/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0364 - sparse_categorical_accuracy: 0.4375 - val_loss: 1.0046 - val_sparse_categorical_accuracy: 0.3750
# Epoch 13/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0327 - sparse_categorical_accuracy: 0.4583 - val_loss: 1.0010 - val_sparse_categorical_accuracy: 0.4167
# Epoch 14/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0293 - sparse_categorical_accuracy: 0.4583 - val_loss: 0.9976 - val_sparse_categorical_accuracy: 0.4583
# Epoch 15/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0255 - sparse_categorical_accuracy: 0.4792 - val_loss: 0.9941 - val_sparse_categorical_accuracy: 0.4583
# Epoch 16/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0219 - sparse_categorical_accuracy: 0.4792 - val_loss: 0.9907 - val_sparse_categorical_accuracy: 0.4583
# Epoch 17/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0185 - sparse_categorical_accuracy: 0.5000 - val_loss: 0.9873 - val_sparse_categorical_accuracy: 0.4583
# Epoch 18/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0150 - sparse_categorical_accuracy: 0.5000 - val_loss: 0.9839 - val_sparse_categorical_accuracy: 0.4583
# Epoch 19/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0117 - sparse_categorical_accuracy: 0.5000 - val_loss: 0.9805 - val_sparse_categorical_accuracy: 0.4583
# Epoch 20/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.0082 - sparse_categorical_accuracy: 0.5104 - val_loss: 0.9772 - val_sparse_categorical_accuracy: 0.4583
# Epoch 21/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.0049 - sparse_categorical_accuracy: 0.5208 - val_loss: 0.9738 - val_sparse_categorical_accuracy: 0.4583
# Epoch 22/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0014 - sparse_categorical_accuracy: 0.5208 - val_loss: 0.9705 - val_sparse_categorical_accuracy: 0.4583
# Epoch 23/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.9981 - sparse_categorical_accuracy: 0.5208 - val_loss: 0.9672 - val_sparse_categorical_accuracy: 0.4583
# Epoch 24/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9948 - sparse_categorical_accuracy: 0.5312 - val_loss: 0.9638 - val_sparse_categorical_accuracy: 0.4583
# Epoch 25/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9915 - sparse_categorical_accuracy: 0.5312 - val_loss: 0.9604 - val_sparse_categorical_accuracy: 0.4583
# Epoch 26/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9881 - sparse_categorical_accuracy: 0.5312 - val_loss: 0.9569 - val_sparse_categorical_accuracy: 0.5000
# Epoch 27/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9849 - sparse_categorical_accuracy: 0.5417 - val_loss: 0.9536 - val_sparse_categorical_accuracy: 0.5000
# Epoch 28/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9815 - sparse_categorical_accuracy: 0.5521 - val_loss: 0.9502 - val_sparse_categorical_accuracy: 0.5000
# Epoch 29/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.9785 - sparse_categorical_accuracy: 0.5521 - val_loss: 0.9469 - val_sparse_categorical_accuracy: 0.5000
# Epoch 30/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9752 - sparse_categorical_accuracy: 0.5521 - val_loss: 0.9437 - val_sparse_categorical_accuracy: 0.5417
# Epoch 31/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9720 - sparse_categorical_accuracy: 0.5625 - val_loss: 0.9404 - val_sparse_categorical_accuracy: 0.5417
# Epoch 32/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.9689 - sparse_categorical_accuracy: 0.5729 - val_loss: 0.9372 - val_sparse_categorical_accuracy: 0.5417
# Epoch 33/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9659 - sparse_categorical_accuracy: 0.5833 - val_loss: 0.9340 - val_sparse_categorical_accuracy: 0.5417
# Epoch 34/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9626 - sparse_categorical_accuracy: 0.5833 - val_loss: 0.9309 - val_sparse_categorical_accuracy: 0.5833
# Epoch 35/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9595 - sparse_categorical_accuracy: 0.6146 - val_loss: 0.9277 - val_sparse_categorical_accuracy: 0.5833
# Epoch 36/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.9565 - sparse_categorical_accuracy: 0.6250 - val_loss: 0.9246 - val_sparse_categorical_accuracy: 0.5833
# Epoch 37/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9533 - sparse_categorical_accuracy: 0.6354 - val_loss: 0.9214 - val_sparse_categorical_accuracy: 0.5833
# Epoch 38/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.9503 - sparse_categorical_accuracy: 0.6354 - val_loss: 0.9183 - val_sparse_categorical_accuracy: 0.5833
# Epoch 39/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9473 - sparse_categorical_accuracy: 0.6354 - val_loss: 0.9151 - val_sparse_categorical_accuracy: 0.5833
# Epoch 40/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.9445 - sparse_categorical_accuracy: 0.6354 - val_loss: 0.9120 - val_sparse_categorical_accuracy: 0.5833
# Epoch 41/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9412 - sparse_categorical_accuracy: 0.6354 - val_loss: 0.9090 - val_sparse_categorical_accuracy: 0.5833
# Epoch 42/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9385 - sparse_categorical_accuracy: 0.6458 - val_loss: 0.9059 - val_sparse_categorical_accuracy: 0.5833
# Epoch 43/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9352 - sparse_categorical_accuracy: 0.6458 - val_loss: 0.9029 - val_sparse_categorical_accuracy: 0.5833
# Epoch 44/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9326 - sparse_categorical_accuracy: 0.6458 - val_loss: 0.8998 - val_sparse_categorical_accuracy: 0.5833
# Epoch 45/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9294 - sparse_categorical_accuracy: 0.6562 - val_loss: 0.8969 - val_sparse_categorical_accuracy: 0.5833
# Epoch 46/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.9264 - sparse_categorical_accuracy: 0.6562 - val_loss: 0.8939 - val_sparse_categorical_accuracy: 0.5833
# Epoch 47/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.9237 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8909 - val_sparse_categorical_accuracy: 0.5833
# Epoch 48/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9209 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8880 - val_sparse_categorical_accuracy: 0.5833
# Epoch 49/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9175 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8851 - val_sparse_categorical_accuracy: 0.5833
# Epoch 50/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9146 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8821 - val_sparse_categorical_accuracy: 0.5833
# Epoch 51/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9117 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8792 - val_sparse_categorical_accuracy: 0.5833
# Epoch 52/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9089 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8763 - val_sparse_categorical_accuracy: 0.5833
# Epoch 53/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9063 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8735 - val_sparse_categorical_accuracy: 0.5833
# Epoch 54/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9031 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8706 - val_sparse_categorical_accuracy: 0.5833
# Epoch 55/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.9004 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8677 - val_sparse_categorical_accuracy: 0.5833
# Epoch 56/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8975 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8649 - val_sparse_categorical_accuracy: 0.5833
# Epoch 57/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8947 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8621 - val_sparse_categorical_accuracy: 0.5833
# Epoch 58/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8917 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8593 - val_sparse_categorical_accuracy: 0.5833
# Epoch 59/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8890 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8566 - val_sparse_categorical_accuracy: 0.5833
# Epoch 60/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8862 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8538 - val_sparse_categorical_accuracy: 0.5833
# Epoch 61/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8834 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8511 - val_sparse_categorical_accuracy: 0.6250
# Epoch 62/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8805 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8484 - val_sparse_categorical_accuracy: 0.6250
# Epoch 63/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8778 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8458 - val_sparse_categorical_accuracy: 0.6250
# Epoch 64/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8750 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.8431 - val_sparse_categorical_accuracy: 0.6250
# Epoch 65/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.8722 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8405 - val_sparse_categorical_accuracy: 0.6250
# Epoch 66/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8694 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8379 - val_sparse_categorical_accuracy: 0.6250
# Epoch 67/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8667 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8353 - val_sparse_categorical_accuracy: 0.6250
# Epoch 68/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8641 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8327 - val_sparse_categorical_accuracy: 0.6250
# Epoch 69/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8615 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8301 - val_sparse_categorical_accuracy: 0.6250
# Epoch 70/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8587 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8276 - val_sparse_categorical_accuracy: 0.6667
# Epoch 71/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8561 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8251 - val_sparse_categorical_accuracy: 0.6667
# Epoch 72/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.8536 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8226 - val_sparse_categorical_accuracy: 0.6667
# Epoch 73/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8511 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8201 - val_sparse_categorical_accuracy: 0.6667
# Epoch 74/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.8482 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8176 - val_sparse_categorical_accuracy: 0.6667
# Epoch 75/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8456 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8152 - val_sparse_categorical_accuracy: 0.6667
# Epoch 76/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8431 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8128 - val_sparse_categorical_accuracy: 0.6667
# Epoch 77/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8406 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8103 - val_sparse_categorical_accuracy: 0.6667
# Epoch 78/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.8380 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8079 - val_sparse_categorical_accuracy: 0.6667
# Epoch 79/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8354 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8055 - val_sparse_categorical_accuracy: 0.6667
# Epoch 80/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8329 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8031 - val_sparse_categorical_accuracy: 0.6667
# Epoch 81/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8303 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.8008 - val_sparse_categorical_accuracy: 0.6667
# Epoch 82/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8278 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.7984 - val_sparse_categorical_accuracy: 0.6667
# Epoch 83/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8252 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.7960 - val_sparse_categorical_accuracy: 0.6667
# Epoch 84/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8228 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.7937 - val_sparse_categorical_accuracy: 0.6667
# Epoch 85/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8204 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.7914 - val_sparse_categorical_accuracy: 0.6667
# Epoch 86/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8177 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.7890 - val_sparse_categorical_accuracy: 0.6667
# Epoch 87/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8151 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.7867 - val_sparse_categorical_accuracy: 0.6667
# Epoch 88/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8126 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.7844 - val_sparse_categorical_accuracy: 0.6667
# Epoch 89/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8101 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.7821 - val_sparse_categorical_accuracy: 0.6667
# Epoch 90/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8077 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.7798 - val_sparse_categorical_accuracy: 0.6667
# Epoch 91/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8051 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.7775 - val_sparse_categorical_accuracy: 0.6667
# Epoch 92/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8028 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7752 - val_sparse_categorical_accuracy: 0.6667
# Epoch 93/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8002 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7729 - val_sparse_categorical_accuracy: 0.6667
# Epoch 94/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7978 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7707 - val_sparse_categorical_accuracy: 0.6667
# Epoch 95/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7953 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7685 - val_sparse_categorical_accuracy: 0.7083
# Epoch 96/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7929 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7663 - val_sparse_categorical_accuracy: 0.7083
# Epoch 97/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.7905 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7641 - val_sparse_categorical_accuracy: 0.7083
# Epoch 98/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7882 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7619 - val_sparse_categorical_accuracy: 0.7083
# Epoch 99/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7856 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7597 - val_sparse_categorical_accuracy: 0.7083
# Epoch 100/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7832 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.7575 - val_sparse_categorical_accuracy: 0.7083

# %% [markdown]
# #### We can also view a summary of the layers within our Sequential model
# To do this, we use the `summary()` method of our model. This will show us layer names, layer type, output shapes, and the number of trainable parameters, which may be useful when developing or comparing models.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 4)                 20
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                50
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 103
# Trainable params: 103
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Plotting training curves: Accuracy and Loss curves
# Here we plot two sets of training curves, the first looks at how the training and validation set accuracy behaves over the epochs trained. The second looks at the loss metric over the epochs.
#
# These plots would allow us to see where we may need to make improvements in my model. For example, if both of the accuuracy curves are still increasing, and the loss is still decreasing, then perhaps my model has not converged, and I can think about training for more epochs. If my training curves are still improving, but my validation curves have stagnated, then maybe overfitting is beginning to occur.
#
# To obtain these plots, we index into the `history.history` dictionary object, using the name of what we wish to plot as the key.

# %%
plt.figure(figsize=[10,5])
plt.subplot(121)
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy',
           'Validation Accuracy'])
plt.title('Accuracy Curves')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss',
           'Validation Loss'])
plt.title('Loss Curves')
plt.show()

# %% [markdown]
# #### We can now evaluate our model to see how it performs on the testing set we created at the start.
# We can use `evaluate()` to see how our model performs on the test set. This will take in the testing data and testing labels, and will return a variable which describes the various metrics we have defined our model to use. In this case it will return a list with the contents \[`loss`, `sparse_categorical_accuracy`\] averaged across our training samples.

# %%
results = model.evaluate(X_tst, y_tst)

print(f'Test set loss: {results[0]:0.2f}, test set accuracy: {results[1]*100:0.2f}%')
# Out:
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7303 - sparse_categorical_accuracy: 0.8000
# Test set loss: 0.73, test set accuracy: 80.00%

# %%
plt.figure(figsize=[10,5])
plt.subplot(121)
plt.scatter(X_tst[:,0], X_tst[:,1], c=y_tst)
plt.ylabel('Feature Dimension 1')
plt.xlabel('Feature Dimension 0')
plt.title('Ground Truth')
plt.subplot(122)
plt.title('Predicted Labels')
plt.xlabel('Feature Dimension 0')
plt.scatter(X_tst[:,0], X_tst[:,1], c=np.argmax(model.predict(X_tst), axis=1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4349             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4350                 colors = mcolors.to_rgba_array(c)
#    4351             except (TypeError, ValueError) as err:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     370
# --> 371     if len(c) == 0:
#     372         return np.zeros((0, 4), float)
#
# TypeError: len() of unsized object
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_69034/1091144248.py in <module>
#       8 plt.title('Predicted Labels')
#       9 plt.xlabel('Feature Dimension 0')
# ---> 10 plt.scatter(X_tst[:,0], X_tst[:,1], c=np.argmax(model.predict(X_tst)))
#      11 plt.show()
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3066         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    3067         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 3068     __ret = gca().scatter(
#    3069         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3070         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4514             orig_edgecolor = kwargs.get('edgecolor', None)
#    4515         c, colors, edgecolors = \
# -> 4516             self._parse_scatter_color_args(
#    4517                 c, edgecolors, kwargs, x.size,
#    4518                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4354                 else:
#    4355                     if not valid_shape:
# -> 4356                         raise invalid_shape_exception(c.size, xsize) from err
#    4357                     # Both the mapping *and* the RGBA conversion failed: pretty
#    4358                     # severe failure => one may appreciate a verbose feedback.
#
# ValueError: 'c' argument has 1 elements, which is inconsistent with 'x' and 'y' with size 30.
